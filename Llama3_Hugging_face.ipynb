# %% [markdown]
# <a href="https://colab.research.google.com/github/yuvizorzi/GeminiReadPDF/blob/main/Llama3_Hugging_face.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Installing dependency

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 104.5 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...

# %%
import json
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig, pipeline

# %% [markdown]
# HF Configure account

# %%
config_data = json.load(open("config.json"))
HF_TOKEN = config_data["HF_TOKEN"]

# %%
#print(HF_TOKEN)

# %%
model_name = "meta-llama/Meta-Llama-3-8B"

# %% [markdown]
# Quantization Configuration

# %%
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16,
)

# %% [markdown]
# loading the Tokenizer and LLM

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name,
                                          token=HF_TOKEN)

tokenizer.pad_token = tokenizer.eos_token
# Out:
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    quantization_config=bnb_config,
    token=HF_TOKEN,
)
# Out:
# config.json:   0%|          | 0.00/654 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# ...
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/177 [00:00<?, ?B/s]

# %% [markdown]
# Text Generater pipeline

# %%
text_generator = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    max_new_tokens=256

)

# %% [markdown]
# Create a function to get response

# %%
def get_response(prompt):
  sequences = text_generator(prompt)
  gen_text = sequences[0]["generated_text"]
  return gen_text

# %%
prompt = "What is MLOps ?, How does it work?"

# %%
llama3_response = get_response(prompt)
llama3_response
# Out:
# 'What is MLOps ?, How does it work? and Why do we need it?\nMLOps is a set of tools and processes that help manage machine learning models in production. It allows data scientists to quickly deploy their models into production, monitor their performance, and make changes as needed. MLOps is essential for data scientists because it helps them manage their models more efficiently, allowing them to focus on building better models rather than worrying about deployment and monitoring. Additionally, MLOps helps data scientists track their models’ performance over time, so they can identify areas for improvement. Finally, MLOps helps data scientists scale their models to meet the needs of their organizations, ensuring that their models are always up-to-date and accurate.\nWhat are the benefits of MLOps?\nMLOps is a set of tools and processes that help data scientists manage their machine learning models in production. MLOps allows data scientists to quickly deploy their models into producti
# ...

# %%
print(llama3_response)
# Out:
# What is MLOps ?, How does it work? and Why do we need it?
# MLOps is a set of tools and processes that help manage machine learning models in production. It allows data scientists to quickly deploy their models into production, monitor their performance, and make changes as needed. MLOps is essential for data scientists because it helps them manage their models more efficiently, allowing them to focus on building better models rather than worrying about deployment and monitoring. Additionally, MLOps helps data scientists track their models’ performance over time, so they can identify areas for improvement. Finally, MLOps helps data scientists scale their models to meet the needs of their organizations, ensuring that their models are always up-to-date and accurate.
# What are the benefits of MLOps?
# ...

# %%
print(llama3_response[len(prompt):])
# Out:
#  and Why do we need it?
# MLOps is a set of tools and processes that help manage machine learning models in production. It allows data scientists to quickly deploy their models into production, monitor their performance, and make changes as needed. MLOps is essential for data scientists because it helps them manage their models more efficiently, allowing them to focus on building better models rather than worrying about deployment and monitoring. Additionally, MLOps helps data scientists track their models’ performance over time, so they can identify areas for improvement. Finally, MLOps helps data scientists scale their models to meet the needs of their organizations, ensuring that their models are always up-to-date and accurate.
# What are the benefits of MLOps?
# ...
